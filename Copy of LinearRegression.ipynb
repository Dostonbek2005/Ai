# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Yangi data
data = {
    "kv_m": [35, 45, 55, 65, 75, 85, 95],
    "narxi": [18000, 25000, 32000, 42000, 53000, 65000, 78000]
}

df = pd.DataFrame(data)

print("🏠 Yangi Uy Ma'lumotlari:")
print(df)

print("\n📊 DataFrame haqida umumiy ma'lumot:")
print(df.info())

print("\n📈 Statistik tahlil:")
print(df.describe())
# Out:
# 🏠 Yangi Uy Ma'lumotlari:
#    kv_m  narxi
# 0    35  18000
# 1    45  25000
# 2    55  32000
# 3    65  42000
# 4    75  53000
# 5    85  65000
# 6    95  78000
#
# 📊 DataFrame haqida umumiy ma'lumot:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   kv_m    7 non-null      int64
#  1   narxi   7 non-null      int64
# dtypes: int64(2)
# memory usage: 244.0 bytes
# None
#
# 📈 Statistik tahlil:
#             kv_m         narxi
# count   7.000000      7.000000
# mean   65.000000  44714.285714
# std    21.602469  21830.515994
# min    35.000000  18000.000000
# 25%    50.000000  28500.000000
# 50%    65.000000  42000.000000
# 75%    80.000000  59000.000000
# max    95.000000  78000.000000

# %%
plt.figure(figsize=(8, 5))
plt.plot(df["kv_m"], df["narxi"], marker='o', color='green')
plt.title("Uy maydoni va narxi o'rtasidagi bog'liqlik")
plt.xlabel("Kvadrat metr")
plt.ylabel("Narxi (ming so'm)")
plt.grid(True)
plt.show()

# %%
import pandas as pd

# Yangi data: mashinaning yoshi va narxi
data = {
    "yosh": [1, 2, 3, 4, 5, 6, 7],
    "narxi": [55000, 50000, 46000, 42000, 37000, 32000, 28000]
}

df = pd.DataFrame(data)

print("🚗 Avtomobillar ma'lumotlar to‘plami:")
print(df)
# Out:
# 🚗 Avtomobillar ma'lumotlar to‘plami:
#    yosh  narxi
# 0     1  55000
# 1     2  50000
# 2     3  46000
# 3     4  42000
# 4     5  37000
# 5     6  32000
# 6     7  28000

# %%
print("\n📊 Statistik ma'lumotlar:")
print(df.describe())
# Out:
# 📊 Statistik ma'lumotlar:
#            yosh         narxi
# count  7.000000      7.000000
# mean   4.000000  41428.571429
# std    2.160247   9727.232269
# min    1.000000  28000.000000
# 25%    2.500000  34500.000000
# 50%    4.000000  42000.000000
# 75%    5.500000  48000.000000
# max    7.000000  55000.000000

# %%
print("\n🔗 Korrelatsiya:")
print(df.corr())
# Out:
# 🔗 Korrelatsiya:
#            yosh     narxi
# yosh   1.000000 -0.999371
# narxi -0.999371  1.000000
